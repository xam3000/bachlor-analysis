# %%
# %matplotlib widget

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("peak_test/android.sensor.accelerometer.csv")

# %%
plt.plot(data.iloc[:,1])
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
